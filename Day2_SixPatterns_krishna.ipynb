# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnaget/ai-mentor-portfolio/blob/main/Day2_SixPatterns_krishna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## cluade Promte-1
#
# https://claude.ai/share/ad321dae-5ede-4f8d-b9be-d7257fe18880

# %% [markdown]
# ChatGpt promte-1
#
# https://chatgpt.com/share/6a0e9c74-91cc-8321-8b74-e1afa36db878

# %% [markdown]
# ## Pattern 1 — PERSONA
# Self-score: 4/5

# %% [markdown]
# Claude promte-2
#
# https://claude.ai/share/f513d0ae-9221-4634-af6f-d24df90f9950

# %% [markdown]
# ChatGpt promte-2
#
# https://chatgpt.com/share/6a0ea27e-b4b0-83a5-8329-fedcba2a6a51

# %% [markdown]
# ## Pattern 2 — FEW-SHOT
#
# Self-score: 3/5

# %% [markdown]
# Cluade promte-3
#
# https://claude.ai/share/d1fd887b-163e-4645-b018-9481eab7fc73

# %% [markdown]
# ChatGpt promte-3
#
# https://chatgpt.com/share/6a0ea3dc-afd0-8322-9508-0c359a36bc86

# %% [markdown]
# ## Pattern 3 — CHAIN-OF-THOUGHT
#
# Self-score: 4/5

# %% [markdown]
# Claude promte-4
#
# https://claude.ai/share/4bd5c24b-8988-42ec-99ad-db89fc574207

# %% [markdown]
# ChatGpt promte-4
#
# https://chatgpt.com/share/6a0ea581-81ac-8324-8233-f3e02cbaa389

# %% [markdown]
# ## Pattern 4 — STRUCTURED OUTPUT
# Did Claude add fences anyway? Yes
#
# Self-score: 3.9/5

# %% [markdown]
# Cluade promte-5
#
# https://claude.ai/share/fc1d9cd2-688c-4e43-9e09-b3fe4c21ba20

# %% [markdown]
# ChatGpt promte-5
#
# https://chatgpt.com/share/6a0ea76c-e050-8320-9a30-edab10278a25

# %% [markdown]
# ## Pattern 5 — SYSTEM PROMPT
# System instruction: ou are a placement coach at an Indian engineering college. You have cracked interviews yourself at Zoho and Freshworks before becoming a coach. You speak like a friendly senior — casual, direct, no fluff. You explain any technical concept in under 80 words with exactly one real-world analogy and one code example. Never use bullet points. Always end with one thing the student should remember for the interview.
# User message: "Explain Dynamic Programming."
#
# Self-score: 5/5

# %% [markdown]
# ChatGpt promte-6
#
# https://chatgpt.com/share/6a0ea971-6bf0-8322-aaa0-66be586a71e8

# %% [markdown]
# ## Pattern 6 — PROMPT CHAINING
#
# Self-score: 4/5

# %% [markdown]
# Claude promte-6
#
# https://claude.ai/share/882333a9-5200-49df-9ad1-d618c84491c1

# %% [markdown]
# | Pattern | Score (0-2) | What I checked |
# |---------|-------------|----------------|
# | 1 Persona | 7/10 | Single intent clear, context nailed, no format instruction, no verify step |
# | 2 Few-Shot | 5/10 | Examples too long, no audience mentioned, model copied wrong style, no verify step |
# | 3 Chain-of-Thought | 8/10 | Best structured prompt, 4 steps clear, no verify step cost 2 points |
# | 4 Structured Output | 6/10 | JSON schema well defined, Claude broke your own format rule by adding fences, no verify step |
# | 5 System Prompt | 8/10 | System prompt did all the work, output shape locked, no verify step |
# | 6 Prompt Chaining | 9/10 | Best output quality, context escalated well, verify step appeared but not explicitly asked |
# | Overall | 43/60 | Pass |
