# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnaget/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the comprehensive skill sets needed for successful AI implementation, from foundational to strategic:
#
# *   **Data & Infrastructure:** The base layer, focused on collecting, storing, processing raw data, and managing the underlying compute resources.
# *   **ML Algorithms & Engineering:** Building upon the data, this layer involves developing, training, validating, and optimizing machine learning models.
# *   **Domain Expertise & AI Application:** Applying AI solutions to real-world problems, requiring deep understanding of specific industries, user needs, and how AI can deliver value.
# *   **Strategic Vision & Ethical Impact:** The pinnacle layer, encompassing AI strategy, leadership, understanding business impact, managing risks, and ensuring responsible, ethical deployment of AI.
